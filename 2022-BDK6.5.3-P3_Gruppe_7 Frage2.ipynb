# %% [markdown]
# # 2022-BDK6.5.3-P3_Gruppe_7
# ## British Library printed music
# ### Frage 3: Welche 5 Komponisten haben die meisten Titel geschrieben (Grafik - Top5)?

# %%
import urllib.request
import pandas as pd
#pandas importieren

# %%
dataset = pd.read_csv("detailedrecords.csv", low_memory=False)
#pull the file

# %%
dataset.head()
#check the head of the file
# Out:
#    BL record ID                   Composer Composer life dates  \
# 0       1279866                        NaN                 NaN
# 1       1312079                        NaN                 NaN
# 2       1706700            Hofhaimer, Paul           1459-1537
# 3       1825532                        NaN                 NaN
# 4       2225270  Chapman, Mary, (Musician)                 NaN
#
#                                                Title  Standardised title  \
# 0            The Penguin book of Canadian Folk songs                 NaN
# 1  Anthology for The musician's guide to theory a...                 NaN
# 2  Harmoniae poeticae Pauli Hofheimeri : viri equ...  Harmoniae poeticae
# 3  Istituzioni e monumenti dell'arte musicale ita...                 NaN
# 4  Eight ball studies suitable for use in girls' ...                 NaN
#
#                                         Other titles  \
# 0                                Canadian folk songs
# ...

# %%
n = 5
dataset['Composer'].value_counts()[:n]
#count the five most Composers
# Out:
# Mozart, Wolfgang Amadeus    7716
# Bach, Johann Sebastian      6877
# Handel, George Frideric     6233
# Beethoven, Ludwig van       5523
# Haydn, Joseph               4603
# Name: Composer, dtype: int64

# %%
n = 5
dataset['Composer'].value_counts()[:n].plot.pie(
                                autopct='%1.0f%%')
#display the five most composers in a pie chart
# Out:
# <AxesSubplot:ylabel='Composer'>
