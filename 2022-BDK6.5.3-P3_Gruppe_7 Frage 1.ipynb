# %% [markdown]
# # 2022-BDK6.5.3-P3_Gruppe_7
# ## British Library printed music
# ### Frage 1: In welchem Jahr wurden die meisten Werke veröffentlicht und wie viele?
# (Top 10)

# %%
import urllib.request
import pandas as pd
#pandas importieren

# %%
dataset = pd.read_csv("detailedrecords.csv", low_memory=False)

#pull the file

# %%
dataset.head (10)
#Check the head of the dataframe
# Out:
#    BL record ID                                           Composer  \
# 0       1279866                                                NaN
# 1       1312079                                                NaN
# 2       1706700                                    Hofhaimer, Paul
# 3       1825532                                                NaN
# 4       2225270                          Chapman, Mary, (Musician)
# 5       3050793                                    Razzi, Serafino
# 6       3081869                             Íslenzka stúdentafélag
# 7       3240772                            Sanchis Guarner, Manuel
# 8       4083483  Liturgies.Latin Rite. Graduals. II. Local. Pas...
# 9       4162358                                                NaN
#
#   Composer life dates                                              Title  \
# 0                 NaN            The Penguin book of Canadian Folk songs
# 1                 NaN  Anthology for The musician's guide to theory a...
# ...

# %%
dataset['Publication date (standardised)'].value_counts()
#cound how many works were published in what year
# Out:
# 1920    10484
# 1910    10120
# 1914     9735
# 1912     9660
# 1923     9519
#         ...
# 1266        1
# 1529        1
# 1345        1
# 1527        1
# 1534        1
# Name: Publication date (standardised), Length: 540, dtype: int64

# %%
dataset['Publication date (standardised)'].value_counts().idxmax()
#find in what year were written the most works
# Out:
# '1920'

# %%
n = 10
dataset['Publication date (standardised)'].value_counts()[:n]
#find the Top10 of the most published in years
# Out:
# 1920    10484
# 1910    10120
# 1914     9735
# 1912     9660
# 1923     9519
# 1913     9452
# 1909     9235
# 1911     9019
# 1922     8988
# 1908     8860
# Name: Publication date (standardised), dtype: int64

# %%
n = 10
dataset['Publication date (standardised)'].value_counts()[:n].plot.barh()
#Build the visualisation
# Out:
# <AxesSubplot:>

# %%
n = 10
dataset['Publication date (standardised)'].value_counts()[:n].plot()
#Build the visualisation 2
# Out:
# <AxesSubplot:>
